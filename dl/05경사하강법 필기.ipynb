# %% [markdown]
# 오차 E와 가중치 간의 함수를 알고 있다고 가정하자
# 가중치를 조절해서 최소 오차값을 도출하자
# 가중치를 어떻게 조절할까?
# 편미분을 통해 특정 점에서 기울기를 보며 가중치를 조절하자

# %% [markdown]
# ![image.png](attachment:image.png)
# 에타 : 학습률

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# hidden layer -> outpu layer
# 가중치 Mmn에서 가중치 wjk 하나 뽑음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 실체가 손에 잡히는 딥러닝, 기초부터 실전 프로그래밍
